# %%
# imports
import pandas as pd 
import requests
import json 
from pprint import pprint
from datetime import datetime
hamiltondf = pd.read_csv('hamiltonONdf.csv')
with open('hamilton_api.json', 'r') as hamilton_data:
    imported_hamilton_data = json.load(hamilton_data)

df_hamiltonbikes = pd.DataFrame(imported_hamilton_data)
df_hamiltonbikes
# Out:
#                                                      network
# company                               [Social Bicycles Inc.]
# gbfs_href  https://hamilton.socialbicycles.com/opendata/g...
# href                              /v2/networks/sobi-hamilton
# id                                             sobi-hamilton
# location   {'city': 'Hamilton, ON', 'country': 'CA', 'lat...
# name                                                    SoBi
# stations   [{'empty_slots': 8, 'extra': {'address': '15 H...

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
#define variables for foursquare and yelp api 
foursquare_clientid = 'HLBSURWJF1WAS4HCUI1KHZTYLJF2IKJ4HQVREGZ0NXUILLMN'
foursquare_clientsecret = 'L0CVGEWLLV30GG4IQ05U0EBSGM4ZWHK2UXNHEYBGP5EHMFDZ'
API_key =  'fsq33muoZk1Jp0hIFMSxk4rrK+8I7iLCElutGSRANiI63cA='

foursquare_url = 'https://api.foursquare.com/v3/places/search'
#request from foursquare

# %%
#request from foursquare 
url = "https://api.foursquare.com/v3/places/search?ll=43.2591%2C-79.8772&radius=1000"
43.259126	-79.877212
headers = {
    "accept": "application/json",
    "Authorization": 'fsq33muoZk1Jp0hIFMSxk4rrK+8I7iLCElutGSRANiI63cA='
}

fsqresponse = requests.get(url, headers=headers)

pprint(fsqresponse.json())
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.2591,
#                                                   'longitude': -79.8772},
#                                        'radius': 1000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#                                        'suffix': '.png'},
#                               'id': 13055,
#                               'name': 'Fried Chicken Joint',
#                               'plural_name': 'Fried Chicken Joints',
#                               'short_name': 'Fried Chicken'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 22,
#               'fsq_id': '5796abdc498eb9b6b1d59458',
#               'geocodes': {'main': {'latitude': 43.259271,
#                                     'longitude': -79.877373},
#                            'roof': {'latitude': 43.259271,
#                                     'longitude': -79.877373}},
#               'link': '/v3/places/5796abdc498eb9b6b1d59458',
#               'location': {'address': '274 King St W',
#                            'address_extended': '# 272',
#                            'country': 'CA',
#                            'cross_street': 'Hess St',
#                            'formatted_address': '274 King St W (Hess St), '
#                                                 'Hamilton ON L8P 1J6',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 1J6',
#                            'region': 'ON'},
#               'name': 'Coop Wicked Chicken Hamilton',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#                                        'suffix': '.png'},
#                               'id': 13055,
#                               'name': 'Fried Chicken Joint',
#                               'plural_name': 'Fried Chicken Joints',
#                               'short_name': 'Fried Chicken'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 24,
#               'fsq_id': '579b8d6b498ea8f02d7fc402',
#               'geocodes': {'main': {'latitude': 43.259153,
#                                     'longitude': -79.877446},
#                            'roof': {'latitude': 43.259153,
#                                     'longitude': -79.877446}},
#               'link': '/v3/places/579b8d6b498ea8f02d7fc402',
#               'location': {'address': '274 King St W',
#                            'address_extended': '# 272',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '274 King St W, Hamilton ON '
#                                                 'L8P 1J6',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 1J6',
#                            'region': 'ON'},
#               'name': 'Coop Hamilton',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#                                        'suffix': '.png'},
#                               'id': 13035,
#                               'name': 'Coffee Shop',
#                               'plural_name': 'Coffee Shops',
#                               'short_name': 'Coffee Shop'}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 83,
#               'fsq_id': '56151620498e131e3dcb19e7',
#               'geocodes': {'drop_off': {'latitude': 43.25919,
#                                         'longitude': -79.878071},
#                            'main': {'latitude': 43.259332,
#                                     'longitude': -79.878032},
#                            'roof': {'latitude': 43.259332,
#                                     'longitude': -79.878032}},
#               'link': '/v3/places/56151620498e131e3dcb19e7',
#               'location': {'address': '300 King St W',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '300 King St W, Hamilton ON '
#                                                 'L8P 1B1',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 1B1',
#                            'region': 'ON'},
#               'name': 'Ark + Anchor',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#                                        'suffix': '.png'},
#                               'id': 16065,
#                               'name': 'Neighborhood',
#                               'plural_name': 'Neighborhoods',
#                               'short_name': 'Neighborhood'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#                                        'suffix': '.png'},
#                               'id': 10039,
#                               'name': 'Music Venue',
#                               'plural_name': 'Music Venues',
#                               'short_name': 'Music Venue'}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 74,
#               'fsq_id': '4c09190935ac9c74b85e85f7',
#               'geocodes': {'drop_off': {'latitude': 43.258433,
#                                         'longitude': -79.87756},
#                            'main': {'latitude': 43.258514,
#                                     'longitude': -79.877755},
#                            'roof': {'latitude': 43.258514,
#                                     'longitude': -79.877755}},
#               'link': '/v3/places/4c09190935ac9c74b85e85f7',
#               'location': {'country': 'CA',
#                            'formatted_address': 'Hamilton ON',
#                            'locality': 'Hamilton',
#                            'region': 'ON'},
#               'name': 'Hess Village',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#                                        'suffix': '.png'},
#                               'id': 13298,
#                               'name': 'Lebanese Restaurant',
#                               'plural_name': 'Lebanese Restaurants',
#                               'short_name': 'Lebanese'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#                                        'suffix': '.png'},
#                               'id': 13302,
#                               'name': 'Mediterranean Restaurant',
#                               'plural_name': 'Mediterranean Restaurants',
#                               'short_name': 'Mediterranean'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#                                        'suffix': '.png'},
#                               'id': 13303,
#                               'name': 'Mexican Restaurant',
#                               'plural_name': 'Mexican Restaurants',
#                               'short_name': 'Mexican'}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 113,
#               'fsq_id': '4c57494d30d82d7fd583d962',
#               'geocodes': {'main': {'latitude': 43.259414,
#                                     'longitude': -79.878417},
#                            'roof': {'latitude': 43.259414,
#                                     'longitude': -79.878417}},
#               'link': '/v3/places/4c57494d30d82d7fd583d962',
#               'location': {'address': '306 King St W',
#                            'country': 'CA',
#                            'cross_street': 'at Queen St',
#                            'formatted_address': '306 King St W (at Queen St), '
#                                                 'Hamilton ON L8P 1B1',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 1B1',
#                            'region': 'ON'},
#               'name': 'La Luna Restaurant Downtown',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar',
#                               'plural_name': 'Bars',
#                               'short_name': 'Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#                                        'suffix': '.png'},
#                               'id': 13049,
#                               'name': 'Diner',
#                               'plural_name': 'Diners',
#                               'short_name': 'Diner'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 88,
#               'fsq_id': '4ba3cb84f964a5202e6038e3',
#               'geocodes': {'main': {'latitude': 43.258338,
#                                     'longitude': -79.877864},
#                            'roof': {'latitude': 43.258338,
#                                     'longitude': -79.877864}},
#               'link': '/v3/places/4ba3cb84f964a5202e6038e3',
#               'location': {'address': '24 Hess St S',
#                            'country': 'CA',
#                            'formatted_address': '24 Hess St S, Hamilton ON L8P '
#                                                 '3M8',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 3M8',
#                            'region': 'ON'},
#               'name': 'Gown & Gavel',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#                                        'suffix': '.png'},
#                               'id': 10000,
#                               'name': 'Arts and Entertainment',
#                               'plural_name': 'Arts and Entertainment',
#                               'short_name': 'Arts & Entertainment'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 177,
#               'fsq_id': '4c078f338a81c9b656592790',
#               'geocodes': {'main': {'latitude': 43.259057,
#                                     'longitude': -79.879423},
#                            'roof': {'latitude': 43.259057,
#                                     'longitude': -79.879423}},
#               'link': '/v3/places/4c078f338a81c9b656592790',
#               'location': {'address': '4 Queen St S',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '4 Queen St S, Hamilton ON L8P '
#                                                 '3R3',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 3R3',
#                            'region': 'ON'},
#               'name': 'Scottish Rite',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#                                        'suffix': '.png'},
#                               'id': 13145,
#                               'name': 'Fast Food Restaurant',
#                               'plural_name': 'Fast Food Restaurants',
#                               'short_name': 'Fast Food'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#                                        'suffix': '.png'},
#                               'id': 13326,
#                               'name': 'Poutine Restaurant',
#                               'plural_name': 'Poutine Restaurants',
#                               'short_name': 'Poutine Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#                                        'suffix': '.png'},
#                               'id': 13383,
#                               'name': 'Steakhouse',
#                               'plural_name': 'Steakhouses',
#                               'short_name': 'Steakhouse'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 140,
#               'fsq_id': '4df7c837fa76bd19925b878b',
#               'geocodes': {'drop_off': {'latitude': 43.258376,
#                                         'longitude': -79.878669},
#                            'main': {'latitude': 43.258502,
#                                     'longitude': -79.878634},
#                            'roof': {'latitude': 43.258502,
#                                     'longitude': -79.878634}},
#               'link': '/v3/places/4df7c837fa76bd19925b878b',
#               'location': {'address': '112 George St',
#                            'country': 'CA',
#                            'cross_street': 'at Queen St. S.',
#                            'formatted_address': '112 George St (at Queen St. '
#                                                 'S.), Hamilton ON L8P 1E2',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 1E2',
#                            'region': 'ON'},
#               'name': "Smoke's Poutinerie",
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant',
#                               'plural_name': 'Restaurants',
#                               'short_name': 'Restaurant'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 300,
#               'fsq_id': '511d7162e4b084a5d1f26958',
#               'geocodes': {'drop_off': {'latitude': 43.25803,
#                                         'longitude': -79.873899},
#                            'main': {'latitude': 43.2582,
#                                     'longitude': -79.873853},
#                            'roof': {'latitude': 43.2582,
#                                     'longitude': -79.873853}},
#               'link': '/v3/places/511d7162e4b084a5d1f26958',
#               'location': {'address': '152 King St W',
#                            'country': 'CA',
#                            'cross_street': 'Bay And King',
#                            'formatted_address': '152 King St W (Bay And King), '
#                                                 'Hamilton ON L8P 1A5',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 1A5',
#                            'region': 'ON'},
#               'name': 'The George Hamilton',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#                                        'suffix': '.png'},
#                               'id': 10027,
#                               'name': 'Museum',
#                               'plural_name': 'Museums',
#                               'short_name': 'Museum'}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 428,
#               'fsq_id': '4b54ef65f964a52006d427e3',
#               'geocodes': {'main': {'latitude': 43.257458,
#                                     'longitude': -79.87215},
#                            'roof': {'latitude': 43.25718,
#                                     'longitude': -79.872568}},
#               'link': '/v3/places/4b54ef65f964a52006d427e3',
#               'location': {'address': '123 King St W',
#                            'country': 'CA',
#                            'cross_street': 'King St. and Bay St.',
#                            'formatted_address': '123 King St W (King St. and '
#                                                 'Bay St.), Hamilton ON L8P 4S8',
#                            'locality': 'Hamilton',
#                            'postcode': 'L8P 4S8',
#                            'region': 'ON'},
#               'name': 'Art Gallery of Hamilton',
#               'related_places': {},
#               'timezone': 'America/Toronto'}]}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
HamiltonPOI_data = fsqresponse.json() 
results = HamiltonPOI_data['results']
for result in results:
    name = result['name']
    location = result['location']   
    pprint(f"Name: {name},Location: {location}")
# Out:
# ("Name: Coop Wicked Chicken Hamilton,Location: {'address': '274 King St W', "
#  "'address_extended': '# 272', 'country': 'CA', 'cross_street': 'Hess St', "
#  "'formatted_address': '274 King St W (Hess St), Hamilton ON L8P 1J6', "
#  "'locality': 'Hamilton', 'postcode': 'L8P 1J6', 'region': 'ON'}")
# ("Name: Coop Hamilton,Location: {'address': '274 King St W', "
#  "'address_extended': '# 272', 'country': 'CA', 'cross_street': '', "
#  "'formatted_address': '274 King St W, Hamilton ON L8P 1J6', 'locality': "
#  "'Hamilton', 'postcode': 'L8P 1J6', 'region': 'ON'}")
# ("Name: Ark + Anchor,Location: {'address': '300 King St W', 'country': 'CA', "
#  "'cross_street': '', 'formatted_address': '300 King St W, Hamilton ON L8P "
#  "1B1', 'locality': 'Hamilton', 'postcode': 'L8P 1B1', 'region': 'ON'}")
# ("Name: Hess Village,Location: {'country': 'CA', 'formatted_address': "
#  "'Hamilton ON', 'locality': 'Hamilton', 'region': 'ON'}")
# ("Name: La Luna Restaurant Downtown,Location: {'address': '306 King St W', "
#  "'country': 'CA', 'cross_street': 'at Queen St', 'formatted_address': '306 "
#  "King St W (at Queen St), Hamilton ON L8P 1B1', 'locality': 'Hamilton', "
#  "'postcode': 'L8P 1B1', 'region': 'ON'}")
# ("Name: Gown & Gavel,Location: {'address': '24 Hess St S', 'country': 'CA', "
#  "'formatted_address': '24 Hess St S, Hamilton ON L8P 3M8', 'locality': "
#  "'Hamilton', 'postcode': 'L8P 3M8', 'region': 'ON'}")
# ("Name: Scottish Rite,Location: {'address': '4 Queen St S', 'country': 'CA', "
#  "'cross_street': '', 'formatted_address': '4 Queen St S, Hamilton ON L8P "
#  "3R3', 'locality': 'Hamilton', 'postcode': 'L8P 3R3', 'region': 'ON'}")
# ("Name: Smoke's Poutinerie,Location: {'address': '112 George St', 'country': "
#  "'CA', 'cross_street': 'at Queen St. S.', 'formatted_address': '112 George St "
#  "(at Queen St. S.), Hamilton ON L8P 1E2', 'locality': 'Hamilton', 'postcode': "
#  "'L8P 1E2', 'region': 'ON'}")
# ("Name: The George Hamilton,Location: {'address': '152 King St W', 'country': "
#  "'CA', 'cross_street': 'Bay And King', 'formatted_address': '152 King St W "
#  "(Bay And King), Hamilton ON L8P 1A5', 'locality': 'Hamilton', 'postcode': "
#  "'L8P 1A5', 'region': 'ON'}")
# ("Name: Art Gallery of Hamilton,Location: {'address': '123 King St W', "
#  "'country': 'CA', 'cross_street': 'King St. and Bay St.', "
#  "'formatted_address': '123 King St W (King St. and Bay St.), Hamilton ON L8P "
#  "4S8', 'locality': 'Hamilton', 'postcode': 'L8P 4S8', 'region': 'ON'}")

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
hamilton_restaurant_data = []

results = HamiltonPOI_data['results']
for result in results:
    name = result['name']
    location = result['location']   
    pprint(f"Name: {name},Location: {location}")
    hamilton_restaurant_data.append([name, location])
hamilton_restaurantDF = pd.DataFrame(hamilton_restaurant_data, columns= ['name','location'])
hamilton_restaurantDF
# Out:
# ("Name: Coop Wicked Chicken Hamilton,Location: {'address': '274 King St W', "
#  "'address_extended': '# 272', 'country': 'CA', 'cross_street': 'Hess St', "
#  "'formatted_address': '274 King St W (Hess St), Hamilton ON L8P 1J6', "
#  "'locality': 'Hamilton', 'postcode': 'L8P 1J6', 'region': 'ON'}")
# ("Name: Coop Hamilton,Location: {'address': '274 King St W', "
#  "'address_extended': '# 272', 'country': 'CA', 'cross_street': '', "
#  "'formatted_address': '274 King St W, Hamilton ON L8P 1J6', 'locality': "
#  "'Hamilton', 'postcode': 'L8P 1J6', 'region': 'ON'}")
# ("Name: Ark + Anchor,Location: {'address': '300 King St W', 'country': 'CA', "
#  "'cross_street': '', 'formatted_address': '300 King St W, Hamilton ON L8P "
#  "1B1', 'locality': 'Hamilton', 'postcode': 'L8P 1B1', 'region': 'ON'}")
# ("Name: Hess Village,Location: {'country': 'CA', 'formatted_address': "
#  "'Hamilton ON', 'locality': 'Hamilton', 'region': 'ON'}")
# ("Name: La Luna Restaurant Downtown,Location: {'address': '306 King St W', "
#  "'country': 'CA', 'cross_street': 'at Queen St', 'formatted_address': '306 "
#  "King St W (at Queen St), Hamilton ON L8P 1B1', 'locality': 'Hamilton', "
#  "'postcode': 'L8P 1B1', 'region': 'ON'}")
# ("Name: Gown & Gavel,Location: {'address': '24 Hess St S', 'country': 'CA', "
#  "'formatted_address': '24 Hess St S, Hamilton ON L8P 3M8', 'locality': "
#  "'Hamilton', 'postcode': 'L8P 3M8', 'region': 'ON'}")
# ("Name: Scottish Rite,Location: {'address': '4 Queen St S', 'country': 'CA', "
#  "'cross_street': '', 'formatted_address': '4 Queen St S, Hamilton ON L8P "
#  "3R3', 'locality': 'Hamilton', 'postcode': 'L8P 3R3', 'region': 'ON'}")
# ("Name: Smoke's Poutinerie,Location: {'address': '112 George St', 'country': "
#  "'CA', 'cross_street': 'at Queen St. S.', 'formatted_address': '112 George St "
#  "(at Queen St. S.), Hamilton ON L8P 1E2', 'locality': 'Hamilton', 'postcode': "
#  "'L8P 1E2', 'region': 'ON'}")
# ("Name: The George Hamilton,Location: {'address': '152 King St W', 'country': "
#  "'CA', 'cross_street': 'Bay And King', 'formatted_address': '152 King St W "
#  "(Bay And King), Hamilton ON L8P 1A5', 'locality': 'Hamilton', 'postcode': "
#  "'L8P 1A5', 'region': 'ON'}")
# ("Name: Art Gallery of Hamilton,Location: {'address': '123 King St W', "
#  "'country': 'CA', 'cross_street': 'King St. and Bay St.', "
#  "'formatted_address': '123 King St W (King St. and Bay St.), Hamilton ON L8P "
#  "4S8', 'locality': 'Hamilton', 'postcode': 'L8P 4S8', 'region': 'ON'}")
#                            name  \
# 0  Coop Wicked Chicken Hamilton
# 1                 Coop Hamilton
# 2                  Ark + Anchor
# 3                  Hess Village
# 4   La Luna Restaurant Downtown
# 5                  Gown & Gavel
# 6                 Scottish Rite
# 7            Smoke's Poutinerie
# 8           The George Hamilton
# 9       Art Gallery of Hamilton
#
#                                             location
# 0  {'address': '274 King St W', 'address_extended...
# 1  {'address': '274 King St W', 'address_extended...
# 2  {'address': '300 King St W', 'country': 'CA', ...
# 3  {'country': 'CA', 'formatted_address': 'Hamilt...
# 4  {'address': '306 King St W', 'country': 'CA', ...
# 5  {'address': '24 Hess St S', 'country': 'CA', '...
# 6  {'address': '4 Queen St S', 'country': 'CA', '...
# 7  {'address': '112 George St', 'country': 'CA', ...
# 8  {'address': '152 King St W', 'country': 'CA', ...
# 9  {'address': '123 King St W', 'country': 'CA', ...

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
yelpurl = "https://api.yelp.com/v3/businesses/search?location=Hamilton%20&latitude=43.2591&longitude=-79.8772&radius=1000&attributes=bike%20&attributes=station&attributes=&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer YpXx2wSm695PC8_kCbX1fDbkvZsjlcc-9x7kc11czARKirVL40yxzFXLbYbKn_ReV2DKDgaDadauOwrXsJNqPMawKIPMMw_4ASzo_Thb0rcJu4wNTOlbybhMYIw0ZXYx"
}

response = requests.get(yelpurl, headers=headers)
pprint(response)
response.json()
# Out:
# <Response [200]>
# {'businesses': [{'id': 'vqyK2q3zJ74TIT1-7Bf3Tg',
#    'alias': 'la-luna-hamilton',
#    'name': 'La Luna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 64,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25942165323912,
#     'longitude': -79.87848757635106},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '306 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1B1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['306 King Street W',
#      'Hamilton, ON L8P 1B1',
#      'Canada']},
#    'phone': '+19055770233',
#    'display_phone': '+1 905-577-0233',
#    'distance': 110.23014710114651},
#   {'id': '9oIPWjU3DvtSdORv6I2toQ',
#    'alias': 'the-ship-hamilton',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 209,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25215, 'longitude': -79.87},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 Augusta Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1P6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['23 Augusta Street',
#      'Hamilton, ON L8N 1P6',
#      'Canada']},
#    'phone': '+19055260792',
#    'display_phone': '+1 905-526-0792',
#    'distance': 967.9883287605744},
#   {'id': 'Q4oLgsU62VPR28pBm0vCXw',
#    'alias': 'earth-to-table-bread-bar-hamilton',
#    'name': 'Earth To Table : Bread Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t-G4g7Hq1wH4ZIWSB-a56g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earth-to-table-bread-bar-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 292,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25284, 'longitude': -79.88702},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '258 Locke Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 4B9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['258 Locke Street S',
#      'Hamilton, ON L8P 4B9',
#      'Canada']},
#    'phone': '+19055222999',
#    'display_phone': '+1 905-522-2999',
#    'distance': 1050.9631855879811},
#   {'id': 'dxsrhzpSxY9wDGbZxhIjHQ',
#    'alias': 'the-coop-hamilton',
#    'name': 'The Coop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GuEVBhD1CNCopbN6GKgMsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coop-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 43,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2591337, 'longitude': -79.8774391},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '274-274 King Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1J6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['274-274 King Street W',
#      'Hamilton, ON L8P 1J6',
#      'Canada']},
#    'phone': '+12897782667',
#    'display_phone': '+1 289-778-2667',
#    'distance': 19.72134787715507},
#   {'id': '752Fv2jKafftvoS3Twkqyg',
#    'alias': 'hambrgr-hamilton',
#    'name': 'Hambrgr',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 202,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25721, 'longitude': -79.8669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['49 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893891212',
#    'display_phone': '+1 289-389-1212',
#    'distance': 857.0455822289796},
#   {'id': 'BcOccyfjH_pfu8Z871iSEQ',
#    'alias': 'ark-and-anchor-hamilton',
#    'name': 'Ark and Anchor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J-ohPx5Qx-lnMudGXWBnHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ark-and-anchor-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2595, 'longitude': -79.87812},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '300 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1B1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['300 King Street W',
#      'Hamilton, ON L8P 1B1',
#      'Canada']},
#    'phone': '+19057519345',
#    'display_phone': '+1 905-751-9345',
#    'distance': 84.18381054954807},
#   {'id': 'bHecMQ85o3ayw1t9hRA90g',
#    'alias': 'the-french-hamilton',
#    'name': 'The French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 98,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25741, 'longitude': -79.86748},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '37 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['37 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055283737',
#    'display_phone': '+1 905-528-3737',
#    'distance': 812.5095225156155},
#   {'id': 'ouKTL8ajZ2BGPRf33xwGWA',
#    'alias': 'pho-nhung-hamilton',
#    'name': 'Pho Nhung',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AIckGv9vQpy1t_2-fewEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-nhung-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 17,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.26239, 'longitude': -79.87797},
#    'transactions': [],
#    'location': {'address1': '85 Queen St N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2V5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['85 Queen St N', 'Hamilton, ON L8R 2V5', 'Canada']},
#    'phone': '+19055258008',
#    'display_phone': '+1 905-525-8008',
#    'distance': 324.90934791571186},
#   {'id': 'xwVB61hW9rpyp6wALR4Apg',
#    'alias': 'berkeley-north-hamilton-2',
#    'name': 'Berkeley North',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 42,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2574045478956,
#     'longitude': -79.8677145254958},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '31 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['31 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055225858',
#    'display_phone': '+1 905-522-5858',
#    'distance': 790.9314870051512},
#   {'id': 'i8nQA6qFkr3TmSCZ1ukbGQ',
#    'alias': 'electric-diner-hamilton',
#    'name': 'Electric Diner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fkpxsQT9L-E5SUA_GoV6sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/electric-diner-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 17,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25845, 'longitude': -79.878},
#    'transactions': [],
#    'location': {'address1': '96 George Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3M8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 George Street', 'Hamilton, ON L8P 3M8', 'Canada']},
#    'phone': '+19055269512',
#    'display_phone': '+1 905-526-9512',
#    'distance': 104.81588512752212},
#   {'id': 'ZgoVlQmApvjWt-0evoeoGQ',
#    'alias': 'moodys-hamilton',
#    'name': 'Moodys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UBfC5iTXK7eMfijJno44MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moodys-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25821, 'longitude': -79.87853},
#    'transactions': [],
#    'location': {'address1': '107 George Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['107 George Street',
#      'Hamilton, ON L8P 1E3',
#      'Canada']},
#    'phone': '+12893096449',
#    'display_phone': '+1 289-309-6449',
#    'distance': 150.63756828963022},
#   {'id': 'XqZOIEbNX7mdIg1Cwb1RWw',
#    'alias': 'famous-recipe-hamilton',
#    'name': 'Famous Recipe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MQR5LySk4evP01v151_oiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/famous-recipe-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 9,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.2580694, 'longitude': -79.8740306},
#    'transactions': [],
#    'location': {'address1': '158 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['158 King Street W',
#      'Hamilton, ON L8P 1A6',
#      'Canada']},
#    'phone': '+12893899740',
#    'display_phone': '+1 289-389-9740',
#    'distance': 281.0788540517348},
#   {'id': '1E7ww2xRfk6GKEw5HRg4qg',
#    'alias': 'papagayo-restaurant-hamilton',
#    'name': 'Papagayo Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EERAEASSNCPJgRdCYBnRMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papagayo-restaurant-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 10,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25902, 'longitude': -79.87646},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '246 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['246 King Street W',
#      'Hamilton, ON L8P 1A9',
#      'Canada']},
#    'phone': '+19055250309',
#    'display_phone': '+1 905-525-0309',
#    'distance': 61.47433954424815},
#   {'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 178,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25726, 'longitude': -79.86713},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['41 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893892555',
#    'display_phone': '+1 289-389-2555',
#    'distance': 832.081202313184},
#   {'id': 'Fkm6WTO7-auG5V4NtzpvRA',
#    'alias': 'amigos-hamilton-2',
#    'name': 'Amigos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qPtXKKbJc0r5tvyWnsYcTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amigos-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 14,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25825, 'longitude': -79.87868},
#    'transactions': [],
#    'location': {'address1': '109 George Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['109 George Street',
#      'Hamilton, ON L8P 1E3',
#      'Canada']},
#    'phone': '+19052671532',
#    'display_phone': '+1 905-267-1532',
#    'distance': 155.1345881052876},
#   {'id': 'TxrfCuyQThzsFUlcFqdqSw',
#    'alias': 'saint-james-espresso-bar-and-eatery-hamilton-2',
#    'name': 'Saint James Espresso Bar & Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-T6LAsL5n5Sa-EyW5vDq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-james-espresso-bar-and-eatery-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 57,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.26098, 'longitude': -79.86693},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '170 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['170 James Street N',
#      'Hamilton, ON L8R 2L1',
#      'Canada']},
#    'phone': '+12893896565',
#    'display_phone': '+1 289-389-6565',
#    'distance': 856.3451474333423},
#   {'id': 'oOxuBeVcfyEExUn2d_FO0A',
#    'alias': 'smokes-poutinerie-hamilton',
#    'name': "Smoke's Poutinerie",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a65ZJuQzh_ZCAtOqMybw4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smokes-poutinerie-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 38,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25854, 'longitude': -79.87863},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '112 George Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['112 George Street',
#      'Hamilton, ON L8P 1E3',
#      'Canada']},
#    'phone': '+12893898779',
#    'display_phone': '+1 289-389-8779',
#    'distance': 128.29499586183766},
#   {'id': 'CH4A4Aa--t0A7bP1VfkMrA',
#    'alias': 'charred-chicken-hamilton',
#    'name': 'Charred Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/agEtNIDjFHSHuMTjDKhipQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charred-chicken-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 118,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2627364, 'longitude': -79.8663839},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '244 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['244 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893960662',
#    'display_phone': '+1 289-396-0662',
#    'distance': 964.6822839284282},
#   {'id': '0vw6fL9m6j_9U4vonPKwGg',
#    'alias': 'buona-vita-pizza-hamilton',
#    'name': 'Buona Vita Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q8repZkQN8V82Aai5-Un5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buona-vita-pizza-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 13,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.262024, 'longitude': -79.8775857},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '82 Queen Street  N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2V4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['82 Queen Street  N',
#      'Hamilton, ON L8R 2V4',
#      'Canada']},
#    'phone': '+19055771000',
#    'display_phone': '+1 905-577-1000',
#    'distance': 326.63029732943625},
#   {'id': 'wZr3xBFhGfYMY-mqwsQuNQ',
#    'alias': 'redchurch-cafe-gallery-hamilton',
#    'name': 'Redchurch Cafe + Gallery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YOAvqZSreEGl_KKsAitDtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redchurch-cafe-gallery-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25551, 'longitude': -79.86725},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['68 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19054070459',
#    'display_phone': '+1 905-407-0459',
#    'distance': 894.5402990819694},
#   {'id': 'uy_vkyImATNvWYzbUCOxyQ',
#    'alias': 'the-burnt-tongue-hamilton-3',
#    'name': 'The Burnt Tongue',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yukiTCTlQbf4xWbb3PwG9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-burnt-tongue-hamilton-3?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 40,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2555538, 'longitude': -79.8858002},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '182 Locke Street S',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 4B3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['182 Locke Street S',
#      'Hamilton, ON L8P 4B3',
#      'Canada']},
#    'phone': '+12893891156',
#    'display_phone': '+1 289-389-1156',
#    'distance': 792.7604326498114},
#   {'id': 'o_CBe1ZQs6kj-Aet2qmL5A',
#    'alias': 'planted-in-hamilton-hamilton',
#    'name': 'Planted in Hamilton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FijjMSlGtfbfgB6jCDSGqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planted-in-hamilton-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 37,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2503352762455,
#     'longitude': -79.8679620207627},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '225 John Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 2C7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['225 John Street S',
#      'Hamilton, ON L8N 2C7',
#      'Canada']},
#    'phone': '+12893896676',
#    'display_phone': '+1 289-389-6676',
#    'distance': 1228.6318715727264},
#   {'id': 'iAxN1bz9JBSG_S1naWHNuw',
#    'alias': 'the-burnt-tongue-hamilton',
#    'name': 'The Burnt Tongue',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fLFESzaFnPVmzT5e4rZqtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-burnt-tongue-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 88,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2605786, 'longitude': -79.8669351},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10 Cannon St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8L 1Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['10 Cannon St E', 'Hamilton, ON L8L 1Z5', 'Canada']},
#    'phone': '+19055361146',
#    'display_phone': '+1 905-536-1146',
#    'distance': 847.3348207421125},
#   {'id': '7LaTBlqKxftS-Or25dGGjQ',
#    'alias': 'bastonis-shawarma-and-grill-hamilton-2',
#    'name': "Bastoni's Shawarma & Grill",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ibRtkPrW3n4anHWQ0rCpHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bastonis-shawarma-and-grill-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 21,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25896, 'longitude': -79.87622},
#    'transactions': [],
#    'location': {'address1': '234 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['234 King Street W',
#      'Hamilton, ON L8P 1A9',
#      'Canada']},
#    'phone': '+12898600177',
#    'display_phone': '+1 289-860-0177',
#    'distance': 83.28138598542613},
#   {'id': 'EGutBSi1dgdaJoLu-LdsTw',
#    'alias': 'august-8-hamilton',
#    'name': 'August 8',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HAndOnz4E-AIgQSaRJTwkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/august-8-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 122,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25943, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Wilson Street',
#     'address2': 'Suite 12',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1 Wilson Street',
#      'Suite 12',
#      'Hamilton, ON L8R',
#      'Canada']},
#    'phone': '+19055243838',
#    'display_phone': '+1 905-524-3838',
#    'distance': 820.3006109630924},
#   {'id': 'WQn811HsoLer6dr0K7GzxA',
#    'alias': 'for-real-dough-hamilton',
#    'name': 'For Real Dough',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kFx4hU2c8lXexWJ4X8mu4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/for-real-dough-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 6,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25911, 'longitude': -79.87676},
#    'transactions': [],
#    'location': {'address1': '256 King Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['256 King Street W',
#      'Hamilton, ON L8P 1A9',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 33.74092107560343},
#   {'id': 'PAVNadox4HMXl-xdsjbjhg',
#    'alias': 'sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton',
#    'name': 'Sagarmatha Curry Palace  Authentic Indian & Nepalese Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9iUar8jsEM4oL7eyBNP2Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 40,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25725, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055226999',
#    'display_phone': '+1 905-522-6999',
#    'distance': 844.9461946248279},
#   {'id': 'xUy8292rGVB_picXiGeQoQ',
#    'alias': 'bronzies-place-hamilton',
#    'name': "Bronzie's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Sve9rY2YfBDzEQw5TmQ2hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronzies-place-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 28,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2505499, 'longitude': -79.87143},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '201 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3A8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['201 James Street S',
#      'Hamilton, ON L8P 3A8',
#      'Canada']},
#    'phone': '+19055293403',
#    'display_phone': '+1 905-529-3403',
#    'distance': 1058.134038437766},
#   {'id': 'RRnbO5NZq716CC8emwWedg',
#    'alias': 'mulberry-coffeehouse-hamilton-2',
#    'name': 'Mulberry Coffeehouse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MlTUR16niJX1HHEmrZrAvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mulberry-coffeehouse-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 75,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.26183, 'longitude': -79.86699},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '193 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['193 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+19059631365',
#    'display_phone': '+1 905-963-1365',
#    'distance': 879.1689515838508},
#   {'id': 'zldX2jhIDUBJzaEPYiSWUQ',
#    'alias': 'radius-hamilton',
#    'name': 'Radius',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9bd_uf5aVnJgtJOFA8BNpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radius-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 92,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.2523512, 'longitude': -79.8708333},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '151 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 2Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['151 James Street S',
#      'Hamilton, ON L8P 2Z5',
#      'Canada']},
#    'phone': '+19053931658',
#    'display_phone': '+1 905-393-1658',
#    'distance': 910.4878053873102},
#   {'id': 'L3zSyRZQEeRzAkkHLgAxtw',
#    'alias': 'lulus-shawarma-hamilton',
#    'name': "Lulu's Shawarma",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Uk_jYB5vS2G4CKPUgY3hEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lulus-shawarma-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 36,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25692, 'longitude': -79.86584},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '32 John Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1H3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['32 John Street N', 'Hamilton, ON L8R 1H3', 'Canada']},
#    'phone': '+19055214848',
#    'display_phone': '+1 905-521-4848',
#    'distance': 946.9561385470769},
#   {'id': 'sNK5Y6JCT5alpLyvjDPceA',
#    'alias': 'the-george-hamilton-hamilton',
#    'name': 'The George Hamilton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XQwklMJjUe6ZygB62vSFEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-george-hamilton-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 20,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.2582505, 'longitude': -79.8737136},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '152 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['152 King Street W',
#      'Hamilton, ON L8P 1A6',
#      'Canada']},
#    'phone': '+19053819820',
#    'display_phone': '+1 905-381-9820',
#    'distance': 297.70999729833915},
#   {'id': 'wNHa-Hze5WuGQjFG9aqdFw',
#    'alias': 'tomah-hamilton-2',
#    'name': 'Tomah',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9Yu7EYdeRlSC0gNmVQOccw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomah-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 7,
#    'categories': [{'alias': 'syrian', 'title': 'Syrian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.25546, 'longitude': -79.88064},
#    'transactions': [],
#    'location': {'address1': '132 Queen Street S',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3S2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['132 Queen Street S',
#      'Hamilton, ON L8P 3S2',
#      'Canada']},
#    'phone': '+19055221919',
#    'display_phone': '+1 905-522-1919',
#    'distance': 491.0053491306021},
#   {'id': '9SSQNmfpLEK_p3otvMVy9Q',
#    'alias': 'born-and-raised-hamilton',
#    'name': 'Born and Raised',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mh_iZEDElgbezdCV5CzSvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/born-and-raised-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 24,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.26235, 'longitude': -79.86626},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '224 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['224 James Street N',
#      'Hamilton, ON L8R 2L3',
#      'Canada']},
#    'phone': '+12897685233',
#    'display_phone': '+1 289-768-5233',
#    'distance': 948.6074255114167},
#   {'id': 'ZWlNFNkwbM5OrwcG2mftxA',
#    'alias': 'mysweetooth-bakery-cafe-hamilton',
#    'name': 'Mysweetooth Bakery Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XiNZ5UwfWRZfVyfZwrvoQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mysweetooth-bakery-cafe-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25802, 'longitude': -79.88216},
#    'transactions': [],
#    'location': {'address1': '301 Main Street W',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1J7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['301 Main Street W',
#      'Hamilton, ON L8P 1J7',
#      'Canada']},
#    'phone': '+13658885686',
#    'display_phone': '+1 365-888-5686',
#    'distance': 418.5007066620832},
#   {'id': 'hqNHaNUTkM_WpzMdfNBWMA',
#    'alias': 'synonym-hamilton',
#    'name': 'Synonym',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fk1s_R2VmN-RiRpKvhN4ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/synonym-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 12,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.264596686727,
#     'longitude': -79.8653724789619},
#    'transactions': [],
#    'location': {'address1': '328 James Street N',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8L 1H2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['328 James Street N',
#      'Hamilton, ON L8L 1H2',
#      'Canada']},
#    'phone': '+19055257974',
#    'display_phone': '+1 905-525-7974',
#    'distance': 1136.1468247102407},
#   {'id': '-1H5kUvew0zbE3F4xD0WHA',
#    'alias': 'durand-coffee-hamilton-2',
#    'name': 'Durand Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y7eA2s8s7Ku9POrEvPSbVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/durand-coffee-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2514262245999,
#     'longitude': -79.8788586258888},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '142 Charlton Avenue W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['142 Charlton Avenue W',
#      'Hamilton, ON L8P',
#      'Canada']},
#    'phone': '+19053939150',
#    'display_phone': '+1 905-393-9150',
#    'distance': 863.7916216038396},
#   {'id': 'zH1IGA8_naVKv4WDqvSOIg',
#    'alias': 'the-west-town-bar-and-grill-hamilton',
#    'name': 'The West Town Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gQyahke0ejmRnNn8y_wrbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-west-town-bar-and-grill-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 49,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25456, 'longitude': -79.88633},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '214 Locke Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 4B4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['214 Locke Street S',
#      'Hamilton, ON L8P 4B4',
#      'Canada']},
#    'phone': '+19055701412',
#    'display_phone': '+1 905-570-1412',
#    'distance': 890.9455432330344},
#   {'id': 'Cg0WEknzjnguRylTcf1pEQ',
#    'alias': 'kenzo-hamilton',
#    'name': 'Kenzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rbxtzsWRIMnxlBbjL-AZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kenzo-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 24,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.256548097485,
#     'longitude': -79.8681968450546},
#    'transactions': [],
#    'location': {'address1': '21 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['21 King Street E', 'Hamilton, ON L8N 1A1', 'Canada']},
#    'phone': '+19055776666',
#    'display_phone': '+1 905-577-6666',
#    'distance': 782.3544772513146},
#   {'id': 'GTAJyJuT_sE0byRLTdM5sA',
#    'alias': 'sapporo-japanese-restaurant-hamilton',
#    'name': 'Sapporo Japanese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e7DRA-E2m2FcdySlQHm7FA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapporo-japanese-restaurant-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 91,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25429, 'longitude': -79.866},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Main St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 Main St E', 'Hamilton, ON L8N 1G3', 'Canada']},
#    'phone': '+19055271668',
#    'display_phone': '+1 905-527-1668',
#    'distance': 1050.1905372011363},
#   {'id': '_Tl4-DH2ci_AVXq028__sg',
#    'alias': 'burrito-boyz-hamilton',
#    'name': 'Burrito Boyz',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tgggN_qHktJbi8y2yyOcOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrito-boyz-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2557373046875,
#     'longitude': -79.8669128417969},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '66 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['66 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19055292699',
#    'display_phone': '+1 905-529-2699',
#    'distance': 913.132812370292},
#   {'id': 'hokatJ4ORfrw_4dClPC16Q',
#    'alias': 'pho-lac-vien-hamilton',
#    'name': 'Pho Lac Vien',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Wi1fkhhRsk_nkJWLLGBIPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-lac-vien-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 19,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2653164, 'longitude': -79.8808978},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '430 York Boulevard',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 3K8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['430 York Boulevard',
#      'Hamilton, ON L8R 3K8',
#      'Canada']},
#    'phone': '+19055223525',
#    'display_phone': '+1 905-522-3525',
#    'distance': 753.298333035437},
#   {'id': 'hSnCy4Ko5F0De0aIXlaNkA',
#    'alias': 'smalls-coffee-hamilton',
#    'name': 'Smalls Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ArNKebeitDPDtJRcvpjlKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smalls-coffee-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2605099, 'longitude': -79.86695},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8 Cannon Street E',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8L 1Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['8 Cannon Street E',
#      'Hamilton, ON L8L 1Z5',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 841.4981977090519},
#   {'id': 'XYZirPf2pYh4BAHb9GbtVA',
#    'alias': 'diplomat-hamilton',
#    'name': 'Diplomat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxoasGf51kBqhL3l4g-kSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diplomat-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 22,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2572440040624,
#     'longitude': -79.8670820519328},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '43 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055234343',
#    'display_phone': '+1 905-523-4343',
#    'distance': 844.9447226129389},
#   {'id': 'Q3urZhGC4If6AGEhzDVqnQ',
#    'alias': 'green-bar-hamilton',
#    'name': 'Green Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iRQG8dfnJJ4SK7vACsBS2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-bar-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 17,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2627485834705,
#     'longitude': -79.8662985122842},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '236 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['236 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893962288',
#    'display_phone': '+1 289-396-2288',
#    'distance': 971.5291738128424},
#   {'id': '8BWj3CORhDKsIkkpdeHL2Q',
#    'alias': 'homemade-noodles-hamilton',
#    'name': 'Homemade Noodles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wW03GZAGEa-tXNn4AfuvQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homemade-noodles-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 7,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2554837113039,
#     'longitude': -79.8649081215262},
#    'transactions': [],
#    'location': {'address1': '135 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1B2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['135 King Street E',
#      'Hamilton, ON L8N 1B2',
#      'Canada']},
#    'phone': '+19057778877',
#    'display_phone': '+1 905-777-8877',
#    'distance': 1073.5650044955566},
#   {'id': '1jd1vBl_feakkOue29NVIQ',
#    'alias': 'meltwich-hamilton',
#    'name': 'Meltwich',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XKxVv7SsbqsNW3al9mjOdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meltwich-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 5,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.25894, 'longitude': -79.87629},
#    'transactions': [],
#    'location': {'address1': '236 King St W',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['236 King St W', 'Hamilton, ON L8P 1A9', 'Canada']},
#    'phone': '+19053089228',
#    'display_phone': '+1 905-308-9228',
#    'distance': 76.76440415698814},
#   {'id': '4QHM1lGCS-qRazoQnRKNgQ',
#    'alias': 'vida-la-pita-hamilton-2',
#    'name': 'Vida La Pita',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xgGqOQE6l6cvfwTFk9j3cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vida-la-pita-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 20,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 43.258400888343466,
#     'longitude': -79.87609164115581},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '217 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['217 King Street W',
#      'Hamilton, ON L8P 1A7',
#      'Canada']},
#    'phone': '+19055294335',
#    'display_phone': '+1 905-529-4335',
#    'distance': 118.73904304406045},
#   {'id': 'ccvY3bOziuqDnBZSAI6CoQ',
#    'alias': 'bon-temps-hamilton-2',
#    'name': 'Bon Temps',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lsHUH8ujrFIOvkA5vF-CTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-temps-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 7,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.25088, 'longitude': -79.86872},
#    'transactions': [],
#    'location': {'address1': '61 Young Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1V1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['61 Young Street', 'Hamilton, ON L8N 1V1', 'Canada']},
#    'phone': '+19055237177',
#    'display_phone': '+1 905-523-7177',
#    'distance': 1147.619916364619},
#   {'id': 'iNswooJmWC80FjUru0E-XA',
#    'alias': 'frank-and-teresas-anchor-bar-hamilton',
#    'name': "Frank & Teresa's Anchor Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PsVSR6xUqLID6hQbxYzHYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frank-and-teresas-anchor-bar-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 47,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 43.2581416, 'longitude': -79.872937},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '120 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['120 King Street W',
#      'Hamilton, ON L8P 1A1',
#      'Canada']},
#    'phone': '+19053087888',
#    'display_phone': '+1 905-308-7888',
#    'distance': 361.2908669575949}],
#  'total': 212,
#  'region': {'center': {'longitude': -79.8772, 'latitude': 43.2591}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
yelpPOIdata = response.json() 
results = yelpPOIdata['businesses']
for result in results:
    name = result['name']
    location = result['location']   
    rating = result['rating']

yelpPOIdata
# Out:
# {'businesses': [{'id': 'vqyK2q3zJ74TIT1-7Bf3Tg',
#    'alias': 'la-luna-hamilton',
#    'name': 'La Luna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 64,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25942165323912,
#     'longitude': -79.87848757635106},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '306 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1B1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['306 King Street W',
#      'Hamilton, ON L8P 1B1',
#      'Canada']},
#    'phone': '+19055770233',
#    'display_phone': '+1 905-577-0233',
#    'distance': 110.23014710114651},
#   {'id': '9oIPWjU3DvtSdORv6I2toQ',
#    'alias': 'the-ship-hamilton',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 209,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25215, 'longitude': -79.87},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 Augusta Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1P6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['23 Augusta Street',
#      'Hamilton, ON L8N 1P6',
#      'Canada']},
#    'phone': '+19055260792',
#    'display_phone': '+1 905-526-0792',
#    'distance': 967.9883287605744},
#   {'id': 'Q4oLgsU62VPR28pBm0vCXw',
#    'alias': 'earth-to-table-bread-bar-hamilton',
#    'name': 'Earth To Table : Bread Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t-G4g7Hq1wH4ZIWSB-a56g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earth-to-table-bread-bar-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 292,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25284, 'longitude': -79.88702},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '258 Locke Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 4B9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['258 Locke Street S',
#      'Hamilton, ON L8P 4B9',
#      'Canada']},
#    'phone': '+19055222999',
#    'display_phone': '+1 905-522-2999',
#    'distance': 1050.9631855879811},
#   {'id': 'dxsrhzpSxY9wDGbZxhIjHQ',
#    'alias': 'the-coop-hamilton',
#    'name': 'The Coop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GuEVBhD1CNCopbN6GKgMsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coop-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 43,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2591337, 'longitude': -79.8774391},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '274-274 King Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1J6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['274-274 King Street W',
#      'Hamilton, ON L8P 1J6',
#      'Canada']},
#    'phone': '+12897782667',
#    'display_phone': '+1 289-778-2667',
#    'distance': 19.72134787715507},
#   {'id': '752Fv2jKafftvoS3Twkqyg',
#    'alias': 'hambrgr-hamilton',
#    'name': 'Hambrgr',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 202,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25721, 'longitude': -79.8669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['49 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893891212',
#    'display_phone': '+1 289-389-1212',
#    'distance': 857.0455822289796},
#   {'id': 'BcOccyfjH_pfu8Z871iSEQ',
#    'alias': 'ark-and-anchor-hamilton',
#    'name': 'Ark and Anchor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J-ohPx5Qx-lnMudGXWBnHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ark-and-anchor-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2595, 'longitude': -79.87812},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '300 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1B1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['300 King Street W',
#      'Hamilton, ON L8P 1B1',
#      'Canada']},
#    'phone': '+19057519345',
#    'display_phone': '+1 905-751-9345',
#    'distance': 84.18381054954807},
#   {'id': 'bHecMQ85o3ayw1t9hRA90g',
#    'alias': 'the-french-hamilton',
#    'name': 'The French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 98,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25741, 'longitude': -79.86748},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '37 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['37 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055283737',
#    'display_phone': '+1 905-528-3737',
#    'distance': 812.5095225156155},
#   {'id': 'ouKTL8ajZ2BGPRf33xwGWA',
#    'alias': 'pho-nhung-hamilton',
#    'name': 'Pho Nhung',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AIckGv9vQpy1t_2-fewEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-nhung-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 17,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.26239, 'longitude': -79.87797},
#    'transactions': [],
#    'location': {'address1': '85 Queen St N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2V5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['85 Queen St N', 'Hamilton, ON L8R 2V5', 'Canada']},
#    'phone': '+19055258008',
#    'display_phone': '+1 905-525-8008',
#    'distance': 324.90934791571186},
#   {'id': 'xwVB61hW9rpyp6wALR4Apg',
#    'alias': 'berkeley-north-hamilton-2',
#    'name': 'Berkeley North',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 42,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2574045478956,
#     'longitude': -79.8677145254958},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '31 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['31 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055225858',
#    'display_phone': '+1 905-522-5858',
#    'distance': 790.9314870051512},
#   {'id': 'i8nQA6qFkr3TmSCZ1ukbGQ',
#    'alias': 'electric-diner-hamilton',
#    'name': 'Electric Diner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fkpxsQT9L-E5SUA_GoV6sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/electric-diner-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 17,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25845, 'longitude': -79.878},
#    'transactions': [],
#    'location': {'address1': '96 George Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3M8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 George Street', 'Hamilton, ON L8P 3M8', 'Canada']},
#    'phone': '+19055269512',
#    'display_phone': '+1 905-526-9512',
#    'distance': 104.81588512752212},
#   {'id': 'ZgoVlQmApvjWt-0evoeoGQ',
#    'alias': 'moodys-hamilton',
#    'name': 'Moodys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UBfC5iTXK7eMfijJno44MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moodys-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25821, 'longitude': -79.87853},
#    'transactions': [],
#    'location': {'address1': '107 George Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['107 George Street',
#      'Hamilton, ON L8P 1E3',
#      'Canada']},
#    'phone': '+12893096449',
#    'display_phone': '+1 289-309-6449',
#    'distance': 150.63756828963022},
#   {'id': 'XqZOIEbNX7mdIg1Cwb1RWw',
#    'alias': 'famous-recipe-hamilton',
#    'name': 'Famous Recipe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MQR5LySk4evP01v151_oiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/famous-recipe-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 9,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.2580694, 'longitude': -79.8740306},
#    'transactions': [],
#    'location': {'address1': '158 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['158 King Street W',
#      'Hamilton, ON L8P 1A6',
#      'Canada']},
#    'phone': '+12893899740',
#    'display_phone': '+1 289-389-9740',
#    'distance': 281.0788540517348},
#   {'id': '1E7ww2xRfk6GKEw5HRg4qg',
#    'alias': 'papagayo-restaurant-hamilton',
#    'name': 'Papagayo Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EERAEASSNCPJgRdCYBnRMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papagayo-restaurant-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 10,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25902, 'longitude': -79.87646},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '246 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['246 King Street W',
#      'Hamilton, ON L8P 1A9',
#      'Canada']},
#    'phone': '+19055250309',
#    'display_phone': '+1 905-525-0309',
#    'distance': 61.47433954424815},
#   {'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 178,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25726, 'longitude': -79.86713},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['41 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893892555',
#    'display_phone': '+1 289-389-2555',
#    'distance': 832.081202313184},
#   {'id': 'Fkm6WTO7-auG5V4NtzpvRA',
#    'alias': 'amigos-hamilton-2',
#    'name': 'Amigos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qPtXKKbJc0r5tvyWnsYcTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amigos-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 14,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25825, 'longitude': -79.87868},
#    'transactions': [],
#    'location': {'address1': '109 George Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['109 George Street',
#      'Hamilton, ON L8P 1E3',
#      'Canada']},
#    'phone': '+19052671532',
#    'display_phone': '+1 905-267-1532',
#    'distance': 155.1345881052876},
#   {'id': 'TxrfCuyQThzsFUlcFqdqSw',
#    'alias': 'saint-james-espresso-bar-and-eatery-hamilton-2',
#    'name': 'Saint James Espresso Bar & Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-T6LAsL5n5Sa-EyW5vDq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-james-espresso-bar-and-eatery-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 57,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.26098, 'longitude': -79.86693},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '170 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['170 James Street N',
#      'Hamilton, ON L8R 2L1',
#      'Canada']},
#    'phone': '+12893896565',
#    'display_phone': '+1 289-389-6565',
#    'distance': 856.3451474333423},
#   {'id': 'oOxuBeVcfyEExUn2d_FO0A',
#    'alias': 'smokes-poutinerie-hamilton',
#    'name': "Smoke's Poutinerie",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a65ZJuQzh_ZCAtOqMybw4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smokes-poutinerie-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 38,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25854, 'longitude': -79.87863},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '112 George Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['112 George Street',
#      'Hamilton, ON L8P 1E3',
#      'Canada']},
#    'phone': '+12893898779',
#    'display_phone': '+1 289-389-8779',
#    'distance': 128.29499586183766},
#   {'id': 'CH4A4Aa--t0A7bP1VfkMrA',
#    'alias': 'charred-chicken-hamilton',
#    'name': 'Charred Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/agEtNIDjFHSHuMTjDKhipQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charred-chicken-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 118,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2627364, 'longitude': -79.8663839},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '244 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['244 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893960662',
#    'display_phone': '+1 289-396-0662',
#    'distance': 964.6822839284282},
#   {'id': '0vw6fL9m6j_9U4vonPKwGg',
#    'alias': 'buona-vita-pizza-hamilton',
#    'name': 'Buona Vita Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q8repZkQN8V82Aai5-Un5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buona-vita-pizza-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 13,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.262024, 'longitude': -79.8775857},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '82 Queen Street  N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2V4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['82 Queen Street  N',
#      'Hamilton, ON L8R 2V4',
#      'Canada']},
#    'phone': '+19055771000',
#    'display_phone': '+1 905-577-1000',
#    'distance': 326.63029732943625},
#   {'id': 'wZr3xBFhGfYMY-mqwsQuNQ',
#    'alias': 'redchurch-cafe-gallery-hamilton',
#    'name': 'Redchurch Cafe + Gallery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YOAvqZSreEGl_KKsAitDtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redchurch-cafe-gallery-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25551, 'longitude': -79.86725},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['68 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19054070459',
#    'display_phone': '+1 905-407-0459',
#    'distance': 894.5402990819694},
#   {'id': 'uy_vkyImATNvWYzbUCOxyQ',
#    'alias': 'the-burnt-tongue-hamilton-3',
#    'name': 'The Burnt Tongue',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yukiTCTlQbf4xWbb3PwG9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-burnt-tongue-hamilton-3?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 40,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2555538, 'longitude': -79.8858002},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '182 Locke Street S',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 4B3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['182 Locke Street S',
#      'Hamilton, ON L8P 4B3',
#      'Canada']},
#    'phone': '+12893891156',
#    'display_phone': '+1 289-389-1156',
#    'distance': 792.7604326498114},
#   {'id': 'o_CBe1ZQs6kj-Aet2qmL5A',
#    'alias': 'planted-in-hamilton-hamilton',
#    'name': 'Planted in Hamilton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FijjMSlGtfbfgB6jCDSGqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planted-in-hamilton-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 37,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2503352762455,
#     'longitude': -79.8679620207627},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '225 John Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 2C7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['225 John Street S',
#      'Hamilton, ON L8N 2C7',
#      'Canada']},
#    'phone': '+12893896676',
#    'display_phone': '+1 289-389-6676',
#    'distance': 1228.6318715727264},
#   {'id': 'iAxN1bz9JBSG_S1naWHNuw',
#    'alias': 'the-burnt-tongue-hamilton',
#    'name': 'The Burnt Tongue',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fLFESzaFnPVmzT5e4rZqtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-burnt-tongue-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 88,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2605786, 'longitude': -79.8669351},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10 Cannon St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8L 1Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['10 Cannon St E', 'Hamilton, ON L8L 1Z5', 'Canada']},
#    'phone': '+19055361146',
#    'display_phone': '+1 905-536-1146',
#    'distance': 847.3348207421125},
#   {'id': '7LaTBlqKxftS-Or25dGGjQ',
#    'alias': 'bastonis-shawarma-and-grill-hamilton-2',
#    'name': "Bastoni's Shawarma & Grill",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ibRtkPrW3n4anHWQ0rCpHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bastonis-shawarma-and-grill-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 21,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25896, 'longitude': -79.87622},
#    'transactions': [],
#    'location': {'address1': '234 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['234 King Street W',
#      'Hamilton, ON L8P 1A9',
#      'Canada']},
#    'phone': '+12898600177',
#    'display_phone': '+1 289-860-0177',
#    'distance': 83.28138598542613},
#   {'id': 'EGutBSi1dgdaJoLu-LdsTw',
#    'alias': 'august-8-hamilton',
#    'name': 'August 8',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HAndOnz4E-AIgQSaRJTwkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/august-8-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 122,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25943, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Wilson Street',
#     'address2': 'Suite 12',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1 Wilson Street',
#      'Suite 12',
#      'Hamilton, ON L8R',
#      'Canada']},
#    'phone': '+19055243838',
#    'display_phone': '+1 905-524-3838',
#    'distance': 820.3006109630924},
#   {'id': 'WQn811HsoLer6dr0K7GzxA',
#    'alias': 'for-real-dough-hamilton',
#    'name': 'For Real Dough',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kFx4hU2c8lXexWJ4X8mu4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/for-real-dough-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 6,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25911, 'longitude': -79.87676},
#    'transactions': [],
#    'location': {'address1': '256 King Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['256 King Street W',
#      'Hamilton, ON L8P 1A9',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 33.74092107560343},
#   {'id': 'PAVNadox4HMXl-xdsjbjhg',
#    'alias': 'sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton',
#    'name': 'Sagarmatha Curry Palace  Authentic Indian & Nepalese Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9iUar8jsEM4oL7eyBNP2Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 40,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25725, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055226999',
#    'display_phone': '+1 905-522-6999',
#    'distance': 844.9461946248279},
#   {'id': 'xUy8292rGVB_picXiGeQoQ',
#    'alias': 'bronzies-place-hamilton',
#    'name': "Bronzie's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Sve9rY2YfBDzEQw5TmQ2hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronzies-place-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 28,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2505499, 'longitude': -79.87143},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '201 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3A8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['201 James Street S',
#      'Hamilton, ON L8P 3A8',
#      'Canada']},
#    'phone': '+19055293403',
#    'display_phone': '+1 905-529-3403',
#    'distance': 1058.134038437766},
#   {'id': 'RRnbO5NZq716CC8emwWedg',
#    'alias': 'mulberry-coffeehouse-hamilton-2',
#    'name': 'Mulberry Coffeehouse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MlTUR16niJX1HHEmrZrAvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mulberry-coffeehouse-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 75,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.26183, 'longitude': -79.86699},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '193 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['193 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+19059631365',
#    'display_phone': '+1 905-963-1365',
#    'distance': 879.1689515838508},
#   {'id': 'zldX2jhIDUBJzaEPYiSWUQ',
#    'alias': 'radius-hamilton',
#    'name': 'Radius',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9bd_uf5aVnJgtJOFA8BNpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radius-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 92,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.2523512, 'longitude': -79.8708333},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '151 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 2Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['151 James Street S',
#      'Hamilton, ON L8P 2Z5',
#      'Canada']},
#    'phone': '+19053931658',
#    'display_phone': '+1 905-393-1658',
#    'distance': 910.4878053873102},
#   {'id': 'L3zSyRZQEeRzAkkHLgAxtw',
#    'alias': 'lulus-shawarma-hamilton',
#    'name': "Lulu's Shawarma",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Uk_jYB5vS2G4CKPUgY3hEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lulus-shawarma-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 36,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25692, 'longitude': -79.86584},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '32 John Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1H3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['32 John Street N', 'Hamilton, ON L8R 1H3', 'Canada']},
#    'phone': '+19055214848',
#    'display_phone': '+1 905-521-4848',
#    'distance': 946.9561385470769},
#   {'id': 'sNK5Y6JCT5alpLyvjDPceA',
#    'alias': 'the-george-hamilton-hamilton',
#    'name': 'The George Hamilton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XQwklMJjUe6ZygB62vSFEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-george-hamilton-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 20,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.2582505, 'longitude': -79.8737136},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '152 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['152 King Street W',
#      'Hamilton, ON L8P 1A6',
#      'Canada']},
#    'phone': '+19053819820',
#    'display_phone': '+1 905-381-9820',
#    'distance': 297.70999729833915},
#   {'id': 'wNHa-Hze5WuGQjFG9aqdFw',
#    'alias': 'tomah-hamilton-2',
#    'name': 'Tomah',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9Yu7EYdeRlSC0gNmVQOccw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomah-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 7,
#    'categories': [{'alias': 'syrian', 'title': 'Syrian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.25546, 'longitude': -79.88064},
#    'transactions': [],
#    'location': {'address1': '132 Queen Street S',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3S2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['132 Queen Street S',
#      'Hamilton, ON L8P 3S2',
#      'Canada']},
#    'phone': '+19055221919',
#    'display_phone': '+1 905-522-1919',
#    'distance': 491.0053491306021},
#   {'id': '9SSQNmfpLEK_p3otvMVy9Q',
#    'alias': 'born-and-raised-hamilton',
#    'name': 'Born and Raised',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mh_iZEDElgbezdCV5CzSvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/born-and-raised-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 24,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.26235, 'longitude': -79.86626},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '224 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['224 James Street N',
#      'Hamilton, ON L8R 2L3',
#      'Canada']},
#    'phone': '+12897685233',
#    'display_phone': '+1 289-768-5233',
#    'distance': 948.6074255114167},
#   {'id': 'ZWlNFNkwbM5OrwcG2mftxA',
#    'alias': 'mysweetooth-bakery-cafe-hamilton',
#    'name': 'Mysweetooth Bakery Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XiNZ5UwfWRZfVyfZwrvoQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mysweetooth-bakery-cafe-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25802, 'longitude': -79.88216},
#    'transactions': [],
#    'location': {'address1': '301 Main Street W',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1J7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['301 Main Street W',
#      'Hamilton, ON L8P 1J7',
#      'Canada']},
#    'phone': '+13658885686',
#    'display_phone': '+1 365-888-5686',
#    'distance': 418.5007066620832},
#   {'id': 'hqNHaNUTkM_WpzMdfNBWMA',
#    'alias': 'synonym-hamilton',
#    'name': 'Synonym',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fk1s_R2VmN-RiRpKvhN4ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/synonym-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 12,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.264596686727,
#     'longitude': -79.8653724789619},
#    'transactions': [],
#    'location': {'address1': '328 James Street N',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8L 1H2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['328 James Street N',
#      'Hamilton, ON L8L 1H2',
#      'Canada']},
#    'phone': '+19055257974',
#    'display_phone': '+1 905-525-7974',
#    'distance': 1136.1468247102407},
#   {'id': '-1H5kUvew0zbE3F4xD0WHA',
#    'alias': 'durand-coffee-hamilton-2',
#    'name': 'Durand Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y7eA2s8s7Ku9POrEvPSbVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/durand-coffee-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2514262245999,
#     'longitude': -79.8788586258888},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '142 Charlton Avenue W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['142 Charlton Avenue W',
#      'Hamilton, ON L8P',
#      'Canada']},
#    'phone': '+19053939150',
#    'display_phone': '+1 905-393-9150',
#    'distance': 863.7916216038396},
#   {'id': 'zH1IGA8_naVKv4WDqvSOIg',
#    'alias': 'the-west-town-bar-and-grill-hamilton',
#    'name': 'The West Town Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gQyahke0ejmRnNn8y_wrbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-west-town-bar-and-grill-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 49,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25456, 'longitude': -79.88633},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '214 Locke Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 4B4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['214 Locke Street S',
#      'Hamilton, ON L8P 4B4',
#      'Canada']},
#    'phone': '+19055701412',
#    'display_phone': '+1 905-570-1412',
#    'distance': 890.9455432330344},
#   {'id': 'Cg0WEknzjnguRylTcf1pEQ',
#    'alias': 'kenzo-hamilton',
#    'name': 'Kenzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rbxtzsWRIMnxlBbjL-AZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kenzo-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 24,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.256548097485,
#     'longitude': -79.8681968450546},
#    'transactions': [],
#    'location': {'address1': '21 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['21 King Street E', 'Hamilton, ON L8N 1A1', 'Canada']},
#    'phone': '+19055776666',
#    'display_phone': '+1 905-577-6666',
#    'distance': 782.3544772513146},
#   {'id': 'GTAJyJuT_sE0byRLTdM5sA',
#    'alias': 'sapporo-japanese-restaurant-hamilton',
#    'name': 'Sapporo Japanese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e7DRA-E2m2FcdySlQHm7FA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapporo-japanese-restaurant-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 91,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.25429, 'longitude': -79.866},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Main St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 Main St E', 'Hamilton, ON L8N 1G3', 'Canada']},
#    'phone': '+19055271668',
#    'display_phone': '+1 905-527-1668',
#    'distance': 1050.1905372011363},
#   {'id': '_Tl4-DH2ci_AVXq028__sg',
#    'alias': 'burrito-boyz-hamilton',
#    'name': 'Burrito Boyz',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tgggN_qHktJbi8y2yyOcOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrito-boyz-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2557373046875,
#     'longitude': -79.8669128417969},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '66 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['66 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19055292699',
#    'display_phone': '+1 905-529-2699',
#    'distance': 913.132812370292},
#   {'id': 'hokatJ4ORfrw_4dClPC16Q',
#    'alias': 'pho-lac-vien-hamilton',
#    'name': 'Pho Lac Vien',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Wi1fkhhRsk_nkJWLLGBIPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-lac-vien-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 19,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2653164, 'longitude': -79.8808978},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '430 York Boulevard',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 3K8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['430 York Boulevard',
#      'Hamilton, ON L8R 3K8',
#      'Canada']},
#    'phone': '+19055223525',
#    'display_phone': '+1 905-522-3525',
#    'distance': 753.298333035437},
#   {'id': 'hSnCy4Ko5F0De0aIXlaNkA',
#    'alias': 'smalls-coffee-hamilton',
#    'name': 'Smalls Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ArNKebeitDPDtJRcvpjlKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smalls-coffee-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2605099, 'longitude': -79.86695},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8 Cannon Street E',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8L 1Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['8 Cannon Street E',
#      'Hamilton, ON L8L 1Z5',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 841.4981977090519},
#   {'id': 'XYZirPf2pYh4BAHb9GbtVA',
#    'alias': 'diplomat-hamilton',
#    'name': 'Diplomat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxoasGf51kBqhL3l4g-kSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diplomat-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 22,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.2572440040624,
#     'longitude': -79.8670820519328},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '43 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055234343',
#    'display_phone': '+1 905-523-4343',
#    'distance': 844.9447226129389},
#   {'id': 'Q3urZhGC4If6AGEhzDVqnQ',
#    'alias': 'green-bar-hamilton',
#    'name': 'Green Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iRQG8dfnJJ4SK7vACsBS2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-bar-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 17,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2627485834705,
#     'longitude': -79.8662985122842},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '236 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['236 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893962288',
#    'display_phone': '+1 289-396-2288',
#    'distance': 971.5291738128424},
#   {'id': '8BWj3CORhDKsIkkpdeHL2Q',
#    'alias': 'homemade-noodles-hamilton',
#    'name': 'Homemade Noodles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wW03GZAGEa-tXNn4AfuvQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homemade-noodles-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 7,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.2554837113039,
#     'longitude': -79.8649081215262},
#    'transactions': [],
#    'location': {'address1': '135 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1B2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['135 King Street E',
#      'Hamilton, ON L8N 1B2',
#      'Canada']},
#    'phone': '+19057778877',
#    'display_phone': '+1 905-777-8877',
#    'distance': 1073.5650044955566},
#   {'id': '1jd1vBl_feakkOue29NVIQ',
#    'alias': 'meltwich-hamilton',
#    'name': 'Meltwich',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XKxVv7SsbqsNW3al9mjOdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meltwich-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 5,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.25894, 'longitude': -79.87629},
#    'transactions': [],
#    'location': {'address1': '236 King St W',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['236 King St W', 'Hamilton, ON L8P 1A9', 'Canada']},
#    'phone': '+19053089228',
#    'display_phone': '+1 905-308-9228',
#    'distance': 76.76440415698814},
#   {'id': '4QHM1lGCS-qRazoQnRKNgQ',
#    'alias': 'vida-la-pita-hamilton-2',
#    'name': 'Vida La Pita',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xgGqOQE6l6cvfwTFk9j3cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vida-la-pita-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 20,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 43.258400888343466,
#     'longitude': -79.87609164115581},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '217 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['217 King Street W',
#      'Hamilton, ON L8P 1A7',
#      'Canada']},
#    'phone': '+19055294335',
#    'display_phone': '+1 905-529-4335',
#    'distance': 118.73904304406045},
#   {'id': 'ccvY3bOziuqDnBZSAI6CoQ',
#    'alias': 'bon-temps-hamilton-2',
#    'name': 'Bon Temps',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lsHUH8ujrFIOvkA5vF-CTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-temps-hamilton-2?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 7,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.25088, 'longitude': -79.86872},
#    'transactions': [],
#    'location': {'address1': '61 Young Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1V1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['61 Young Street', 'Hamilton, ON L8N 1V1', 'Canada']},
#    'phone': '+19055237177',
#    'display_phone': '+1 905-523-7177',
#    'distance': 1147.619916364619},
#   {'id': 'iNswooJmWC80FjUru0E-XA',
#    'alias': 'frank-and-teresas-anchor-bar-hamilton',
#    'name': "Frank & Teresa's Anchor Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PsVSR6xUqLID6hQbxYzHYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frank-and-teresas-anchor-bar-hamilton?adjust_creative=beUWpC2d3sdtobjDpHPP7Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=beUWpC2d3sdtobjDpHPP7Q',
#    'review_count': 47,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 43.2581416, 'longitude': -79.872937},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '120 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['120 King Street W',
#      'Hamilton, ON L8P 1A1',
#      'Canada']},
#    'phone': '+19053087888',
#    'display_phone': '+1 905-308-7888',
#    'distance': 361.2908669575949}],
#  'total': 212,
#  'region': {'center': {'longitude': -79.8772, 'latitude': 43.2591}}}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
yelprestaurantdata = []

results = yelpPOIdata['businesses']
for result in results:
    name = result['name']
    location = result['location']   
    rating = result['rating']
    yelprestaurantdata.append([name, location, rating])
yelprestaurantDF = pd.DataFrame(yelprestaurantdata, columns= ['name','location','rating'])
yelprestaurantDF
# Out:
#                                                  name  \
# 0                                             La Luna
# 1                                            The Ship
# 2                          Earth To Table : Bread Bar
# 3                                            The Coop
# 4                                             Hambrgr
# 5                                      Ark and Anchor
# 6                                          The French
# 7                                           Pho Nhung
# 8                                      Berkeley North
# 9                                      Electric Diner
# 10                                             Moodys
# 11                                      Famous Recipe
# 12                                Papagayo Restaurant
# 13                                           The Mule
# 14                                             Amigos
# 15                  Saint James Espresso Bar & Eatery
# 16                                 Smoke's Poutinerie
# 17                                    Charred Chicken
# 18                                   Buona Vita Pizza
# 19                           Redchurch Cafe + Gallery
# 20                                   The Burnt Tongue
# 21                                Planted in Hamilton
# 22                                   The Burnt Tongue
# 23                         Bastoni's Shawarma & Grill
# 24                                           August 8
# 25                                     For Real Dough
# 26  Sagarmatha Curry Palace  Authentic Indian & Ne...
# 27                                    Bronzie's Place
# 28                               Mulberry Coffeehouse
# 29                                             Radius
# 30                                    Lulu's Shawarma
# 31                                The George Hamilton
# 32                                              Tomah
# 33                                    Born and Raised
# 34                            Mysweetooth Bakery Cafe
# 35                                            Synonym
# 36                                      Durand Coffee
# 37                          The West Town Bar & Grill
# 38                                              Kenzo
# 39                        Sapporo Japanese Restaurant
# 40                                       Burrito Boyz
# 41                                       Pho Lac Vien
# 42                                      Smalls Coffee
# 43                                           Diplomat
# 44                                          Green Bar
# 45                                   Homemade Noodles
# 46                                           Meltwich
# 47                                       Vida La Pita
# 48                                          Bon Temps
# 49                        Frank & Teresa's Anchor Bar
#
#                                              location  rating
# 0   {'address1': '306 King Street W', 'address2': ...     4.0
# 1   {'address1': '23 Augusta Street', 'address2': ...     4.0
# 2   {'address1': '258 Locke Street S', 'address2':...     4.0
# 3   {'address1': '274-274 King Street W', 'address...     4.0
# 4   {'address1': '49 King William Street', 'addres...     4.0
# 5   {'address1': '300 King Street W', 'address2': ...     4.5
# 6   {'address1': '37 King William Street', 'addres...     4.0
# 7   {'address1': '85 Queen St N', 'address2': None...     4.5
# 8   {'address1': '31 King William Street', 'addres...     4.5
# 9   {'address1': '96 George Street', 'address2': '...     3.5
# 10  {'address1': '107 George Street', 'address2': ...     4.0
# 11  {'address1': '158 King Street W', 'address2': ...     5.0
# 12  {'address1': '246 King Street W', 'address2': ...     4.0
# 13  {'address1': '41 King William Street', 'addres...     4.0
# 14  {'address1': '109 George Street', 'address2': ...     4.5
# 15  {'address1': '170 James Street N', 'address2':...     4.5
# 16  {'address1': '112 George Street', 'address2': ...     3.5
# 17  {'address1': '244 James Street N', 'address2':...     4.0
# 18  {'address1': '82 Queen Street  N', 'address2':...     4.5
# 19  {'address1': '68 King Street E', 'address2': '...     4.5
# 20  {'address1': '182 Locke Street S', 'address2':...     4.5
# 21  {'address1': '225 John Street S', 'address2': ...     4.5
# 22  {'address1': '10 Cannon St E', 'address2': '',...     4.0
# 23  {'address1': '234 King Street W', 'address2': ...     4.0
# 24  {'address1': '1 Wilson Street', 'address2': 'S...     4.0
# 25  {'address1': '256 King Street W', 'address2': ...     3.5
# 26  {'address1': '43 King William Street', 'addres...     4.0
# 27  {'address1': '201 James Street S', 'address2':...     4.5
# 28  {'address1': '193 James Street N', 'address2':...     4.0
# 29  {'address1': '151 James Street S', 'address2':...     3.0
# 30  {'address1': '32 John Street N', 'address2': '...     4.0
# 31  {'address1': '152 King Street W', 'address2': ...     3.5
# 32  {'address1': '132 Queen Street S', 'address2':...     5.0
# 33  {'address1': '224 James Street N', 'address2':...     3.5
# 34  {'address1': '301 Main Street W', 'address2': ...     4.5
# 35  {'address1': '328 James Street N', 'address2':...     4.5
# 36  {'address1': '142 Charlton Avenue W', 'address...     4.5
# 37  {'address1': '214 Locke Street S', 'address2':...     3.5
# 38  {'address1': '21 King Street E', 'address2': '...     4.0
# 39  {'address1': '96 Main St E', 'address2': '', '...     3.5
# 40  {'address1': '66 King Street E', 'address2': '...     4.0
# 41  {'address1': '430 York Boulevard', 'address2':...     4.0
# 42  {'address1': '8 Cannon Street E', 'address2': ...     4.5
# 43  {'address1': '43 King William Street', 'addres...     4.0
# 44  {'address1': '236 James Street N', 'address2':...     4.5
# 45  {'address1': '135 King Street E', 'address2': ...     4.5
# 46  {'address1': '236 King St W', 'address2': '', ...     3.0
# 47  {'address1': '217 King Street W', 'address2': ...     2.5
# 48  {'address1': '61 Young Street', 'address2': No...     5.0
# 49  {'address1': '120 King Street W', 'address2': ...     2.5

# %%
yelprestaurantDF.to_csv("yelpdf.csv", index=False)

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# YELP API gave me way more data, in yelp i got 49 entries in my data frame for restaurants in hamilton with a radius of 1000
# where as the foursquare api only gave me 9 entries for the same condtions

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
yelprestaurantDF = yelprestaurantDF.sort_values(by="rating", ascending=False)

top10_restaurants = yelprestaurantDF.head(10)

top10_restaurants
# Out:
#                                  name  \
# 32                              Tomah
# 11                      Famous Recipe
# 48                          Bon Temps
# 27                    Bronzie's Place
# 21                Planted in Hamilton
# 20                   The Burnt Tongue
# 44                          Green Bar
# 18                   Buona Vita Pizza
# 45                   Homemade Noodles
# 15  Saint James Espresso Bar & Eatery
#
#                                              location  rating
# 32  {'address1': '132 Queen Street S', 'address2':...     5.0
# 11  {'address1': '158 King Street W', 'address2': ...     5.0
# 48  {'address1': '61 Young Street', 'address2': No...     5.0
# 27  {'address1': '201 James Street S', 'address2':...     4.5
# 21  {'address1': '225 John Street S', 'address2': ...     4.5
# 20  {'address1': '182 Locke Street S', 'address2':...     4.5
# 44  {'address1': '236 James Street N', 'address2':...     4.5
# 18  {'address1': '82 Queen Street  N', 'address2':...     4.5
# 45  {'address1': '135 King Street E', 'address2': ...     4.5
# 15  {'address1': '170 James Street N', 'address2':...     4.5
